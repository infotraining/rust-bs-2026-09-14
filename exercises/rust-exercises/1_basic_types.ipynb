// %% [markdown]
// # Variables

// %% [markdown]
// ## Binding & mutablity

// %% [markdown]
// 1. A variable can be used only if it has been initialized.

// %%
// Fix the error below with least amount of modification to the code
fn main() {
    let x: i32; // Uninitialized but used, ERROR !
    let y: i32; // Uninitialized but also unused, only a Warning !

    assert_eq!(x, 5);
    println!("Success!");
}

main();
// Out:
// [E0381] Error: used binding `x` isn't initialized
//    ╭─[ command_6:1:1 ]
//    │
//  6 │     assert_eq!(x, 5);
//    │     ────────┬───────
//    │             ╰───────── `x` used here but it isn't initialized
//    │
//    ├─[ command_6:1:1 ]
//    │
//  3 │     let x: i32; // Uninitialized but used, ERROR !
//    │         ┬     │
//    │         ╰─────── binding declared here but left uninitialized
//    │               │
//    │               ╰─ help: consider assigning a value: ` = 42`
// ───╯
// [unused_variables] Error: unused variable: `y`
//    ╭─[ command_6:1:1 ]
//    │
//  4 │     let y: i32; // Uninitialized but also unused, only a Warning !
//    │         ┬
//    │         ╰── warning: unused variable: `y`
//    │         │
//    │         ╰── help: if this is intentional, prefix it with an underscore: `_y`
// ───╯

// %% [markdown]
// 2. Use mut to mark a variable as mutable.

// %%
// Fill the blanks in the code to make it compile
fn main() {
    let __ __ = 1;
    __ += 2; 
    
    assert_eq!(x, 3);
    println!("Success!");
}

main();
// Out:
// Error: expected one of `:`, `;`, `=`, `@`, or `|`, found `__`
//    ╭─[ command_4:1:1 ]
//    │
//  3 │     let __ __ = 1;
//    │            ─┬
//    │             ╰── expected one of `:`, `;`, `=`, `@`, or `|`
// ───╯

// %% [markdown]
// ## Destructuring

// %% [markdown]
// 3. We can use a pattern with let to destructure a tuple to separate variables.

// %%
// Fix the error below with least amount of modification
fn main() {
    let (x, y) = (1, 2);
    x += 2;

    assert_eq!(x, 3);
    assert_eq!(y, 2);

    println!("Success!");
}

main();
// Out:
// [E0384] Error: cannot assign twice to immutable variable `x`
//    ╭─[ command_7:1:1 ]
//    │
//  3 │     let (x, y) = (1, 2);
//    │          ┬
//    │          ╰── first assignment to `x`
//  4 │     x += 2;
//    │     ───┬──
//    │        ╰──── cannot assign twice to immutable variable
//    │
//    ├─[ command_7:1:1 ]
//    │
//  3 │     let (x, y) = (1, 2);
//    │          │
//    │          ╰─ help: consider making this binding mutable: `mut `
//    │          │
//    │          ╰─ help: to modify the original value, take a borrow instead: `ref mut `
//    │
//    │ Note: You can change an existing variable to mutable like: `let mut x = x;`
// ───╯

// %% [markdown]
// 4. Use tuple, slice, and struct patterns as the left-hand side of an assignment.

// %%
fn main() {
    let (x, y);
    (x,..) = (3, 4);
    [.., y] = [1, 2];
    // Fill the blank to make the code work
    assert_eq!([x,y], __);

    println!("Success!");
} 

main();
// Out:
// [E0425] Error: cannot find value `__` in this scope
//    ╭─[ command_8:1:1 ]
//    │
//  6 │     assert_eq!([x,y], __);
//    │                       ─┬
//    │                        ╰── not found in this scope
// ───╯

// %% [markdown]
// # Basic Types

// %% [markdown]
// 1. Types are inferred by the compiler.

// %%
// Remove something to make it work
fn main() {
    let x: i32 = 5;
    let mut y: u32 = 5;

    y = x;
    
    let z = 10; // Type of z ? 
    assert!((&z as &dyn std::any::Any).is::<__>());

    println!("Success!");
}

main();
// Out:
// [E0425] Error: cannot find type `__` in this scope
//    ╭─[ command_9:1:1 ]
//    │
//  9 │     assert!((&z as &dyn std::any::Any).is::<__>());
//    │                                             ─┬
//    │                                              ╰── not found in this scope
// ───╯
// [E0308] Error: mismatched types
//    ╭─[ command_9:1:1 ]
//    │
//  6 │     y = x;
//    │         ┬
//    │         ╰── expected `u32`, found `i32`
//    │
//    ├─[ command_9:1:1 ]
//    │
//  4 │     let mut y: u32 = 5;
//    │                ─┬─
//    │                 ╰─── expected due to this type
// ───╯

// %% [markdown]
// 2. Cast types using the `as` keyword.

// %%
// Fill the blank
fn main() {
    let v: u16 = 38_u8 as __;

    println!("Success!");
}

main();
// Out:
// [E0425] Error: cannot find type `__` in this scope
//    ╭─[ command_10:1:1 ]
//    │
//  3 │     let v: u16 = 38_u8 as __;
//    │                           ─┬
//    │                            ╰── not found in this scope
// ───╯

// %% [markdown]
// 3. Guess the type inferred by the compiler.

// %%
// Get the type of given variable, return a string representation of the type  , e.g "i8", "u8", "i32", "u32"
fn type_of<T>(_: &T) -> String {
    format!("{}", std::any::type_name::<T>())
}

// Modify `assert_eq!` to make it work
fn main() {
    let x = 5;
    assert_eq!("__".to_string(), type_of(&x));

    println!("Success!");
}

main();
// Out:
// thread '<unnamed>' (33684) panicked at src\lib.rs:5:5:
// assertion `left == right` failed
//   left: "__"
//  right: "i32"
// stack backtrace:
//    0: std::panicking::panic_handler
//              at /rustc/48a229ceaefd4985c50990b14116b6d856af0985/library\std\src\panicking.rs:679
//    1: core::panicking::panic_fmt
//              at /rustc/48a229ceaefd4985c50990b14116b6d856af0985/library\core\src\panicking.rs:80
//    2: core::panicking::assert_failed_inner
//              at /rustc/48a229ceaefd4985c50990b14116b6d856af0985/library\core\src\panicking.rs:439
//    3: core::panicking::assert_failed::<alloc::string::String, alloc::string::String>
//    4: run_user_code_2
//    5: <unknown>
//    6: <unknown>
//    7: <unknown>
//    8: <unknown>
//    9: <unknown>
//   10: <unknown>
//   11: <unknown>
//   12: <unknown>
//   13: BaseThreadInitThunk
//   14: RtlUserThreadStart
// note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.

// %% [markdown]
// 2. Type `char` represents a single Unicode scalar value.

// %%
// Make it work
use std::mem::size_of_val;

fn main() {
    let c1 = 'a';
    assert_eq!(size_of_val(&c1), __); 

    let c2 = '❤'; // heart utf-8
    assert_eq!(size_of_val(&c2), __); 

    println!("Success!");
} 

main();

// %% [markdown]
// 3. Unit type `()` has only one value `()`.

// %%
// Make it work, don't modify `implicitly_ret_unit` !
fn main() {
    let _v: () = ();

    let v = (1, 2);
    assert_eq!(v, implicitly_ret_unit());

    println!("Success!");
}

fn implicitly_ret_unit() {
    println!("I will return a ()");
}

// Don't use this one
fn explicitly_ret_unit() -> () {
    println!("I will return a ()");
}

main();

// %%
use std::mem::size_of_val;

fn main() {
    let unit: () = ();
    assert!(size_of_val(&unit) == __);

    println!("Success!");
}

main();

// %% [markdown]
// # Statements & Expressions

// %%
// Make it work with two ways
fn main() {
    let v = {
        let mut x = 1;
        x += 2
    };
 
    assert_eq!(v, 3);
 
    println!("Success!");
 }

 main();

// %%
fn main() {
    let s = sum(1 , 2);
    assert_eq!(s, 3);

    println!("Success!");
}

fn sum(x: i32, y: i32) -> i32 {
    x + y;
}

main();

// %% [markdown]
// # Functions

// %%
fn main() {
    // Don't modify the following two lines!
    let (x, y) = (1, 2);
    let s = sum(x, y);

    assert_eq!(s, 3);

    println!("Success!");
}

fn sum(x, y: i32) {
    x + y;
}

main();

// %%
fn main() {
    print();
 }
 
 // Replace i32 with another type
 fn print() -> i32 {
    println!("Success!");
 }

 main();
