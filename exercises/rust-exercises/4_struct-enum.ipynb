// %% [markdown]
// # Struct

// %% [markdown]
// 1.

// %%
// Fix the error
#[derive(Debug)]
struct Person {
    name: String,
    age: u8,
    hobby: String
}

fn main() {
    let age = 30;
    let p = Person {
        name: String::from("sunface"),
        age,
        hobby: String::from("coding"),
    };

    println!("{:?}", p);

    println!("Success!");
} 

main();
// Out:
// Person { name: "sunface", age: 30, hobby: "coding" }
// Success!

// %% [markdown]
// 2.

// %%
// Fix the errors and fill the blanks
struct Color(i32, i32, i32);

fn main() {
    let v = Color(0, 127, 255);
    check_color(v);

    println!("Success!");
}   

fn check_color(p: Color) {
    let Color(r, g, b) = p;
    assert_eq!(r, 0);
    assert_eq!(g, 127);
    assert_eq!(b, 255);
 }

 main();
// Out:
// Success!

// %% [markdown]
// 3.

// %%
// Fill the blank and fix the error without adding/removing new line
#[derive(Debug)]
struct Person {
    name: String,
    age: u8,
}

fn main() {
    let age = 18;

    let mut p = Person {
        name: String::from("john"),
        age,
    };

    println!("{:?}", p);

    // How can you believe sunface is only 18? 
    p.age = 30;

    // Fill the blank
    p.name = String::from("John");

    println!("{:?}", p);

    println!("Success!");
}

main();
// Out:
// Person { name: "john", age: 18 }
// Person { name: "John", age: 30 }
// Success!

// %% [markdown]
// 4.

// %%
// Fill the blank to make the code work
#[derive(Debug)]
struct User {
    active: bool,
    username: String,
    email: String,
    sign_in_count: u64,
}
fn main() {
    let u1 = User {
        email: String::from("someone@example.com"),
        username: String::from("sunface"),
        active: true,
        sign_in_count: 1,
    };
    println!("u1: {:?}", u1);

    let u2 = set_email(u1);

    println!("u2: {:?}", u2);
    println!("Success!");
} 

fn set_email(u: User) -> User {
    User {
        email: String::from("contact@im.dev"),
        ..u
    }
}

main();
// Out:
// u1: User { active: true, username: "sunface", email: "someone@example.com", sign_in_count: 1 }
// u2: User { active: true, username: "sunface", email: "contact@im.dev", sign_in_count: 1 }
// Success!

// %% [markdown]
// 5.

// %%
// Fill the blanks to make the code work
#[derive(Debug, Copy, Clone, PartialEq, Eq)]
struct Rectangle {
    width: u32,
    height: u32,
}

fn main() {
    let scale = 2;
    let rect1 = Rectangle {
        width: dbg!(30 * scale), // Print debug info to stderr and assign the value of  `30 * scale` to `width`
        height: 50,
    };

    dbg!(&rect1); // Print debug info to stderr

    println!("{:?}", rect1); // Print debug info to stdout
}

main();
// Out:
// [src\lib.rs:39:16] 30 * scale = 60
// [src\lib.rs:43:5] &rect1 = Rectangle {
//     width: 60,
//     height: 50,
// }
// Rectangle { width: 60, height: 50 }

// %% [markdown]
// # Enum

// %% [markdown]
// 1.

// %%
// Fix the errors
enum Number {
    Zero,
    One,
    Two,
}

enum Number1 {
    Zero = 0,
    One,
    Two,
}

// C-like enum
enum Number2 {
    Zero = 0,
    One = 1,
    Two = 2,
}


fn main() {
    // An enum variant can be converted to a integer by `as`
    assert_eq!(Number::One, Number1::One);
    assert_eq!(Number1::One, Number2::One);

    println!("Success!");
} 

main();

// %% [markdown]
// 2.

// %%
// Fill in the blank
enum Message {
    Quit,
    Move { x: i32, y: i32 },
    Write(String),
    ChangeColor(i32, i32, i32),
}

fn main() {
    let msg1 = Message::Move{__}; // Instantiating with x = 1, y = 2 
    let msg2 = Message::Write(__); // Instantiating with "hello, world!"

    println!("Success!");
} 

main();

// %% [markdown]
// 3.

// %%
// Fill in the blank and fix the error
enum Message {
    Quit,
    Move { x: i32, y: i32 },
    Write(String),
    ChangeColor(i32, i32, i32),
}

fn main() {
    let msg = Message::Move{x: 1, y: 2};

    if let Message::Move{__} = msg {
        assert_eq!(a, b);
    } else {
        panic!("NEVER LET THIS RUN！");
    }

    println!("Success!");
} 

main();

// %% [markdown]
// 4.

// %%
// Fill in the blank and fix the errors
enum Message {
    Quit,
    Move { x: i32, y: i32 },
    Write(String),
    ChangeColor(i32, i32, i32),
}

fn main() {
    let msgs: __ = [
        Message::Quit,
        Message::Move{x:1, y:3},
        Message::ChangeColor(255,255,0)
    ];

    for msg in msgs {
        show_message(msg)
    }
} 

fn show_message(msg: Message) {
    println!("{}", msg);
}

main();

// %% [markdown]
// # Impl

// %% [markdown]
// 1. Implement functions for `struct`

// %%
struct ContactEntry(String, String);

// TODO: implement functions for ContactEntry

fn main() {
    let c1 = ContactEntry::new("John", "666-66-66-66");
    
    assert_eq!(c1.name(), "John");
    assert_eq!(c1.phone(), "666-66-66-66");    
}
